# %%
import googlemaps
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
gmaps = googlemaps.Client(key=os.getenv("key"))

# Geocoding an address
places_result = gmaps.places('Starbucks, Amsterdam')

# %%
places_result
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCAwEAAPAhLr2H2PxPTGGlpshtA9M4DigZxD7JrLQj4bjLLrtF8DYrRVRxl8UOyvr_VWz0mbHUYI7ZBre-rHaJ8Fr8oCQyhhPXQ7-_lCOPGYW-aKNkyk44Gw3ysEfJfy64g4NgUvwoEQs4Tb2OILrVlHbVyskpanIGH13p0Tba-lkLtNLzaIS2oBr_29BEGcj3NtqHCcape_6laGzgpVIPNXbdhpC-85dBAgHWQ9a0kuH54NpczuGYdpSgVP9TH-UkRUwYcYZfQaQx08b7Vmiyl17icLEs8vepUkqnym1BsLAWCJZkpZUvzcIMxy073UfaRe5Y45yMtVXrbCH1cH43v34AzxxoiA7MQrnv_kXlEndTAHGxEhBy8CjNd4UBEkaKBZgFRQtXGhTu-jjgR9EjIa0lJ-NXc9SVaeoOJQ',
#  'results': [{'formatted_address': 'Damrak 80-81, 1012 LN Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.37429770000001, 'lng': 4.8942746},
#     'viewport': {'northeast': {'lat': 52.37559837989272,
#       'lng': 4.895823579892723},
#      'southwest': {'lat': 52.37289872010727, 'lng': 4.893123920107279}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'eaeaec5b4f71ee84549782b64f5d3f2a00f923f0',
#    'name': 'STARBUCKS COFFEE Amsterdam Damrak Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103168607838999802856/photos">Lee Ross</a>'],
#      'photo_reference': 'CmRaAAAAFcKvWjnUcLgsd6sJ5MJYnRrZrmj86DsIlOFGWHqjSkGgjB3sWZWjWxKQsSP-1NFr8ZPwGTYwqXD2IqiRW7yQfJvdTkQ-cc6DAcaJUH7V2yGWxsyr1kBK8T_i2ny8S3UeEhBVJGxrpomJy02WNgKaGK9SGhQSMGhU4zAa8XBilbCksjJDy3KNbg',
#      'width': 4032}],
#    'place_id': 'ChIJmR4_c8cJxkcRzOFSDlo6rIE',
#    'plus_code': {'compound_code': '9VFV+PP Amsterdam, Netherlands',
#     'global_code': '9F469VFV+PP'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJmR4_c8cJxkcRzOFSDlo6rIE',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 2821},
#   {'formatted_address': 'Singel 480, 1017 AW Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.36699789999999, 'lng': 4.8896652},
#     'viewport': {'northeast': {'lat': 52.36824857989272, 'lng': 4.89498235},
#      'southwest': {'lat': 52.36554892010728, 'lng': 4.88776615}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'd095f2656ca3b7453b3384c40fba9e1cabc2b109',
#    'name': 'STARBUCKS COFFEE Bloemenmarkt Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113888148515894040032/photos">Raffaele Privitera</a>'],
#      'photo_reference': 'CmRaAAAAo3ZBlFaEt3hD9EgC5DXZgLqsivvaQm67mBPc6Obf2MrRcW4G4ZLA9sOa6Y4Ddwsk0IiyvzE6bnKRFTUptRt1YwlbdAjFVTBEqWF82TkpkaLjgHVSUCyBOAcLxqlRYuS0EhCTNLi7xWCRliucsVUmCv7sGhRQl2ziLmQ5gLDVeeUFnctGxLicZQ',
#      'width': 2268}],
#    'place_id': 'ChIJn0Sv38EJxkcROZ0fqZDXz78',
#    'plus_code': {'compound_code': '9V8Q+QV Amsterdam, Netherlands',
#     'global_code': '9F469V8Q+QV'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJn0Sv38EJxkcROZ0fqZDXz78',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 780},
#   {'formatted_address': 'Ferdinand Bolstraat 21580, 1072 LM Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3553881, 'lng': 4.8905951},
#     'viewport': {'northeast': {'lat': 52.35676327989272,
#       'lng': 4.891846079892722},
#      'southwest': {'lat': 52.35406362010728, 'lng': 4.889146420107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '2677837fffd78901e8c814161aee009b5df792f5',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102813368529171175482/photos">Лена Курамшина</a>'],
#      'photo_reference': 'CmRaAAAAV8ZwdoBrpU6DLldYJ904mQ8PsC0LydD9kDzWnAyPxvEqJQDf7gZtmbV2X0bTyM0Hpt-pKTrLT2Jf8v4pWLWV754e8fWu9xQKoBYQZufSnFB9GcjR96iRKZUKBE6VJ1J2EhDaNONcRlyvcNlC8oM9C4anGhT4xD1yf0y9zV1Emz46-fVTPO8Rmw',
#      'width': 1080}],
#    'place_id': 'ChIJG_MZl_IJxkcR33lePMhXgnE',
#    'plus_code': {'compound_code': '9V4R+56 Amsterdam, Netherlands',
#     'global_code': '9F469V4R+56'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJG_MZl_IJxkcR33lePMhXgnE',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 515},
#   {'formatted_address': 'Leidsestraat 101, 1017 NZ Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.36448240000001, 'lng': 4.8836336},
#     'viewport': {'northeast': {'lat': 52.36607492989272,
#       'lng': 4.885273579892721},
#      'southwest': {'lat': 52.36337527010728, 'lng': 4.882573920107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'dbdc22ef98c9361e5823edf56b4b397516ce501a',
#    'name': 'STARBUCKS COFFEE Leidsestraat Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118149578868575755031/photos">Taylan Özgür ÇELİK</a>'],
#      'photo_reference': 'CmRaAAAAscQuoHGbtVrZNsR8VB5OjVhbEEdiGAiWYfw5AWZHsFMUUzP42NMp9XpchlQ6_r-mk_hsKziJTazIHHJzW_ThHersy0Rmsp8s-xNXjERewjrKeGL4-5z08_3xU7ifw2DsEhByj72hRfdPLDCwM31X4Tk5GhRK8-O7_snGeVIV1ZUYXCWFOESWbA',
#      'width': 3024}],
#    'place_id': 'ChIJlVbUV-gJxkcRHHmmM_0RSNI',
#    'plus_code': {'compound_code': '9V7M+QF Amsterdam, Netherlands',
#     'global_code': '9F469V7M+QF'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJlVbUV-gJxkcRHHmmM_0RSNI',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 1058},
#   {'formatted_address': 'Ground Floor, Oosterdokskade 4, 1001 RD Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.37687829999999, 'lng': 4.9043465},
#     'viewport': {'northeast': {'lat': 52.37821097989271,
#       'lng': 4.905410279892721},
#      'southwest': {'lat': 52.37551132010727, 'lng': 4.902710620107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '2ce34b124941b21a48e327aeffb1800ae7276f26',
#    'name': 'STARBUCKS COFFEE Doubletree by Hilton Amsterdam Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116306321173754987078/photos">Cristina Bregant</a>'],
#      'photo_reference': 'CmRaAAAAOcmGg31GqP91bDoeX97oDCiyB4sA5jPEYe4F4FqJ89d2lXWV301xLtWpIm5YguEbfPxWVP6qhI6QnYFFfiVM7Ka6j8rVEtLK2IzCzTJ46pCtm0LVSoDrBPZ28bItSC0NEhDSRwxyR7l5PoKgvh15hZc3GhRSMLMP2HfbJ5QtHStNJf83T6x2Xg',
#      'width': 2336}],
#    'place_id': 'ChIJi2rFCboJxkcRC6rJWGwJJcE',
#    'plus_code': {'compound_code': '9WG3+QP Amsterdam, Netherlands',
#     'global_code': '9F469WG3+QP'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJi2rFCboJxkcRC6rJWGwJJcE',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 1211},
#   {'formatted_address': 'The Bank Rembrandtplein, Utrechtsestraat 9, 1017 CV Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3659541, 'lng': 4.8977405},
#     'viewport': {'northeast': {'lat': 52.36726757989273,
#       'lng': 4.899002479892721},
#      'southwest': {'lat': 52.36456792010728, 'lng': 4.896302820107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '80f6629e0c7cf2a95ca655fb623eb8a307d1de4a',
#    'name': 'STARBUCKS The Bank Rembrandtplein',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112505112973275371412/photos">F Kheribet</a>'],
#      'photo_reference': 'CmRaAAAA3T4fqnYIHI2n3p8yqX1TxMZ9zjLUURZEctTlhLDZNPR9PsQHcwW9j_ViVQjVHhNXC6GXS_H7t38v5-HOtRYVR6_TWfHG8BovSlTiSDDTXhKfgu2Z5siZChHP3q-uxgwWEhDhcNy4jpX6FSNmwaXYpMkxGhS6gAYNQbAoyF4hvESXDIqkZuwLXQ',
#      'width': 3024}],
#    'place_id': 'ChIJt5OxeZUJxkcRZj-1erhRI-Y',
#    'plus_code': {'compound_code': '9V8X+93 Amsterdam, Netherlands',
#     'global_code': '9F469V8X+93'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJt5OxeZUJxkcRZj-1erhRI-Y',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 1685},
#   {'formatted_address': 'Overtoom 72, 1054 HL Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.36311569999999, 'lng': 4.8758273},
#     'viewport': {'northeast': {'lat': 52.36438922989272,
#       'lng': 4.877225779892721},
#      'southwest': {'lat': 52.36168957010727, 'lng': 4.874526120107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '9bce13add972c07f5a1970d7eda795a1ef08d49c',
#    'name': 'STARBUCKS COFFEE Amsterdam Overtoom Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110371000214334359144/photos">110371000214334359144</a>'],
#      'photo_reference': 'CmRaAAAAsbWtxftKxXbhb6HDU7Ch48k_vXDftq2pfCRwN4kFt_6NEqJvp09jnYGWB_f0imhIiNg3vfwGtO1NLQLGSw0usYJQa0XzS39JZobQfKRvP3_AwmH_ktVwQHpji-6c4QeXEhADJCThtW6T-CEu5ZX5Al0FGhQd7_jk7eU55wR5f5ZZvR7ZgeMaPw',
#      'width': 3096}],
#    'place_id': 'ChIJgyToluYJxkcRztyQbyl0S7U',
#    'plus_code': {'compound_code': '9V7G+68 Amsterdam, Netherlands',
#     'global_code': '9F469V7G+68'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJgyToluYJxkcRztyQbyl0S7U',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 604},
#   {'formatted_address': 'Zuidplein 10, 1077 XV Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.33961009999999, 'lng': 4.8731287},
#     'viewport': {'northeast': {'lat': 52.34100547989272,
#       'lng': 4.874652379892721},
#      'southwest': {'lat': 52.33830582010728, 'lng': 4.871952720107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '0515d910b912d9a86ce9d39628c6d0938a0ba567',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112234864539954373443/photos">DAVID SMITH JACKSSON</a>'],
#      'photo_reference': 'CmRaAAAAVmlgH6kHpYP1Osh39AGjaRkqA-VZ_aMMtYdmdg_5gASbfH0jo6VcXh-iyo5cvNfRTanBthmiCgdBK-q8-EkYteiKVdGn0fYer303vtw8IemVBG8OSCTeQwo3UCeHMesFEhC_lFx_TjNHpelDj6iRP3LIGhTJGkbkotBakuTQzcZHuIQV-PwGsQ',
#      'width': 1440}],
#    'place_id': 'ChIJKcZLagQKxkcRhJRSA5rKCb4',
#    'plus_code': {'compound_code': '8VQF+R7 Amsterdam, Netherlands',
#     'global_code': '9F468VQF+R7'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJKcZLagQKxkcRhJRSA5rKCb4',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 482},
#   {'formatted_address': 'Stationsplein 9, 1012 AB Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.37904899999999,
#      'lng': 4.900354099999999},
#     'viewport': {'northeast': {'lat': 52.38035937989272,
#       'lng': 4.901739179892721},
#      'southwest': {'lat': 52.37765972010727, 'lng': 4.899039520107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'e9250d5ff9184c70e0303ffa768f0fd061b2203e',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116444004257627204745/photos">Ann Hwang</a>'],
#      'photo_reference': 'CmRaAAAADD_Kya-CovIhOpQsyDoqv5bR6w2FKUPICB-WqCZGnBddNdKibLMsMbBGWBG_IjLZo-u7tBiEwGLLgfXdOApz5e5-cu5fki0UYDzXvW2kfnabG6ed1kntThjfdq0MFPgZEhDC59LoOk9T1A1VdBqE6OWRGhQlwsC8S9139MBSdsE3GZAv-x5aog',
#      'width': 4032}],
#    'place_id': 'ChIJswJXpLcJxkcRzN8fUklLDnQ',
#    'plus_code': {'compound_code': '9WH2+J4 Amsterdam, Netherlands',
#     'global_code': '9F469WH2+J4'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJswJXpLcJxkcRzN8fUklLDnQ',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 766},
#   {'formatted_address': 'ArenA Boulevard 618, 1011 DS Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3121749, 'lng': 4.947705},
#     'viewport': {'northeast': {'lat': 52.31353477989272,
#       'lng': 4.949298379892721},
#      'southwest': {'lat': 52.31083512010728, 'lng': 4.946598720107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '47015d834d9e9f9484e7775c9f45fc39ba0125b9',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108777129081399369935/photos">Sharon Jukhoo</a>'],
#      'photo_reference': 'CmRaAAAA8T-t1W2M99ctUW74uZHhrXqsESr9MTtI1nJlEpjAvspUqdX61xggHIDFEItt-m2WEU7ZoShuW9gchYT9I8HyiPi55sYamfq1GZyg0mZNuTP8GCX7SXy9ZyP37Cpyy8xzEhB3OSB_eXe2HAsI23ygd8u4GhTKcQNPeKoAEZZIzLxbuabZdFNKYQ',
#      'width': 2988}],
#    'place_id': 'ChIJ9xUTPZcLxkcRL6QHAEXnrsE',
#    'plus_code': {'compound_code': '8W6X+V3 Amsterdam, Netherlands',
#     'global_code': '9F468W6X+V3'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJ9xUTPZcLxkcRL6QHAEXnrsE',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 313},
#   {'formatted_address': 'Beethovenstraat 36-38, 1077 JH Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3493467, 'lng': 4.8771144},
#     'viewport': {'northeast': {'lat': 52.35065782989272,
#       'lng': 4.878561179892722},
#      'southwest': {'lat': 52.34795817010727, 'lng': 4.875861520107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '29db38cbc44a6fa24105c7f7b721b3cb9cf04328',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108241465481297141594/photos">rahma ali</a>'],
#      'photo_reference': 'CmRaAAAAY8LiVE5cYcO2tXc8QvCjmBUJr157kBM_bxnPxnmeEciLLbq7qKzDfPRFgfVEu4HastCQ9fWwH30H0tq5nPbzVbUjQf9YpGYaNL1uiwX9KfzkagblWjtSC9MjnWCdceskEhA6utnGYE2zQX5SPRDlThl4GhS6EU7jE8kO-3O7o768rKO3rlw5Vw',
#      'width': 3024}],
#    'place_id': 'ChIJpz-Xz_kJxkcRxofN-_h5SUo',
#    'plus_code': {'compound_code': '8VXG+PR Amsterdam, Netherlands',
#     'global_code': '9F468VXG+PR'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJpz-Xz_kJxkcRxofN-_h5SUo',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 294},
#   {'formatted_address': 'Orlyplein 103, 1043 DT Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3892232, 'lng': 4.8375534},
#     'viewport': {'northeast': {'lat': 52.39054652989272,
#       'lng': 4.839030829892722},
#      'southwest': {'lat': 52.38784687010728, 'lng': 4.836331170107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '24de62e6f3b55fbb95749846991c7f4c30a3f0a9',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111685520909383163466/photos">Max Kolodziejczyk</a>'],
#      'photo_reference': 'CmRaAAAADC8rVtJLIhfhXHmMAT5tP2f6cm2bFZ0rx5maoW14WR6eaiWFkufrFUjJfsGnuV-bjc6_hJHjxKfxlPzg8wqbKeBZmfctxWrzZmTRLPfM6NVXF6CthiqrGJGwlxwLaYpwEhD0ad8vIp6hBdnb0q9witRfGhS_WDU1OO_NFtYKY6VyAomCAg6oGg',
#      'width': 2322}],
#    'place_id': 'ChIJWWG8uFjixUcRYAZqX1edmLU',
#    'plus_code': {'compound_code': '9RQQ+M2 Amsterdam, Netherlands',
#     'global_code': '9F469RQQ+M2'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJWWG8uFjixUcRYAZqX1edmLU',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 411},
#   {'formatted_address': 'Julianaplein 1, 1097 DN Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3464775, 'lng': 4.917986099999999},
#     'viewport': {'northeast': {'lat': 52.34796197989272,
#       'lng': 4.919982379892721},
#      'southwest': {'lat': 52.34526232010727, 'lng': 4.917282720107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'd828da78f81dc11f0ecd064c7a30454cb07a76c3',
#    'name': 'Starbucks Amsterdam Amstel Station',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101774680148204012817/photos">Monique Schultze</a>'],
#      'photo_reference': 'CmRaAAAAT9eAbdyGkxthjP-7pW70KAIwo3xYkQ0mM91SavZV_NIikoRgvkoI1go-siQThU6w_3zI-NvWsTKWSyYfxQOFMkmNQXR0dP64ruYprOY66tXLLcAaFMOUyNvjgUoLHEuQEhBLK1zmhMmXFlvYaGxnsNfHGhS4WVppQehIJRxuShtZdTOX7Dgk9Q',
#      'width': 3024}],
#    'place_id': 'ChIJK4fYhX8JxkcRnmEQGyN8QM4',
#    'plus_code': {'compound_code': '8WW9+H5 Amsterdam, Netherlands',
#     'global_code': '9F468WW9+H5'},
#    'price_level': 2,
#    'rating': 3.5,
#    'reference': 'ChIJK4fYhX8JxkcRnmEQGyN8QM4',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 39},
#   {'formatted_address': 'Meibergdreef 9, 1105 AZ Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.2940851, 'lng': 4.9571149},
#     'viewport': {'northeast': {'lat': 52.29559262989272,
#       'lng': 4.957802729892721},
#      'southwest': {'lat': 52.29289297010727, 'lng': 4.955103070107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '4faeb7afb0385a714fd21d908274283a70e2b3ae',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100365925025782360648/photos">Ndyuka-Art Plein</a>'],
#      'photo_reference': 'CmRaAAAAMTqnT3KY_EcZyC1e2iJaFqWg6CW0HQvOt3D_R7_k5ow2AgnQFqlRoNtAVZpjW-ZiqDgMb5eTvFOXAy44idcWl-5zcY9D1PMr7PlgIkLsfRNrLtaq62Ej_qedtGrtn9j4EhBFpfWZWSA7-nA-chUoXZvCGhTNMuIVU5fbCNVaXyb3QkjN9GPgFw',
#      'width': 2988}],
#    'place_id': 'ChIJR2WRgH4LxkcRceiIYcLexS8',
#    'plus_code': {'compound_code': '7XV4+JR Amsterdam, Netherlands',
#     'global_code': '9F467XV4+JR'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJR2WRgH4LxkcRceiIYcLexS8',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 25},
#   {'formatted_address': 'Rokin 74, 1012 KW Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3703102, 'lng': 4.892257499999999},
#     'viewport': {'northeast': {'lat': 52.37165732989272,
#       'lng': 4.893812279892721},
#      'southwest': {'lat': 52.36895767010728, 'lng': 4.891112620107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'a5d92d79064f1ae3a238958c60a923002b056de3',
#    'name': 'Starbucks Amsterdam Rokin',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116437287697815031226/photos">Jm Alamri</a>'],
#      'photo_reference': 'CmRaAAAAsXWgfCyRSYuzZnwbvBh-S_K-2nDhtKtZN2X8fKeHC0bMKrc5A54wF9ISlZse-EF7_im0spMImCMmTHBoV-QFJE2LWq6klo-NTFpESGc_kxmv2gXdUBDU29bojqc3TQvKEhDux1_wcwZySpkpryStBJ8iGhRPWy4OTYQaGCi-HTVSEP5TNh3QNA',
#      'width': 3024}],
#    'place_id': 'ChIJ-cK0IYAJxkcRIGSJZb9VXrU',
#    'plus_code': {'compound_code': '9VCR+4W Amsterdam, Netherlands',
#     'global_code': '9F469VCR+4W'},
#    'rating': 4.2,
#    'reference': 'ChIJ-cK0IYAJxkcRIGSJZb9VXrU',
#    'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 97},
#   {'formatted_address': 'Europaboulevard 24, 1083 AD Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.32816709999999, 'lng': 4.8896519},
#     'viewport': {'northeast': {'lat': 52.32951667989272,
#       'lng': 4.891075379892722},
#      'southwest': {'lat': 52.32681702010728, 'lng': 4.888375720107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '71822fadfc8821eb3eb646afea66befa3446f770',
#    'name': 'Starbucks on the go',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111528768746659145693/photos">Volkan YAZAR</a>'],
#      'photo_reference': 'CmRaAAAAAJq6f1IjqbpmxQhCbn2EceGfDfwaeKKAtCfh3miRXOphErp6trr2mw4XyZ_XQvZDPnUahkbJXlRaL6-NEhkKiiIYpkwZXb4NP-8z3yEeemt8ixvtm7UuL6iLovSzlbAjEhBa1M3ansLIkkgWvti8fO0zGhSVOMLSU-USgAdU7WsiK5tuZM4oSg',
#      'width': 2448}],
#    'place_id': 'ChIJc9PFQT4KxkcRrSw-pBut7Qs',
#    'plus_code': {'compound_code': '8VHQ+7V Amsterdam, Netherlands',
#     'global_code': '9F468VHQ+7V'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJc9PFQT4KxkcRrSw-pBut7Qs',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 35},
#   {'formatted_address': 'Stationsplein 38B, 1012 AB Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3798957, 'lng': 4.9005785},
#     'viewport': {'northeast': {'lat': 52.38121877989273,
#       'lng': 4.901998879892721},
#      'southwest': {'lat': 52.37851912010728, 'lng': 4.899299220107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '22f095dc77fa6c93f1e7983a45b1cf9e3d4a0534',
#    'name': 'Starbucks IJHal',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100421600136521853311/photos">Jens Hoffmann</a>'],
#      'photo_reference': 'CmRaAAAAbyC1d7Qi2zsyvAr0WjBakw_kFwesEGpWjoFPLkV123eqAwbxYOM9Q7-5aHVZtSzTOrFsgQBs9G-PKtX2msIRC59vEHiaASO2oCVsveuIcmb4SvTtfEhG8Hk8Bd5n1QklEhCgMdeqGnjh2I7CXldAbPtBGhRI0IcpybS6VWh7Xzu7V4gxlFRuRA',
#      'width': 1080}],
#    'place_id': 'ChIJa3RJuOAJxkcR8bQ_XJU9jdw',
#    'plus_code': {'compound_code': '9WH2+X6 Amsterdam, Netherlands',
#     'global_code': '9F469WH2+X6'},
#    'rating': 4,
#    'reference': 'ChIJa3RJuOAJxkcR8bQ_XJU9jdw',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 312},
#   {'formatted_address': 'Gustav Mahlerlaan 841a, 1082 MA Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.3364927, 'lng': 4.870430199999999},
#     'viewport': {'northeast': {'lat': 52.33793212989272,
#       'lng': 4.871777079892722},
#      'southwest': {'lat': 52.33523247010728, 'lng': 4.869077420107279}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '176395680f625c7c25f92425715ed387a982a4ab',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110552992471171923592/photos">Reda Noaimy</a>'],
#      'photo_reference': 'CmRaAAAAmvr4RBZhqoBKMFq_kdljfK7lhArru_6d8PDHR2T8wvR2PE6OIN5VoCE5vXE_X659xP-N7kHeYY9IUu_awOc3QyR4WxN5342Oh-QcjALPlV5WKWXTzphRVFTvh-NBq-veEhDwtVC22ObIsanKG4YzkCKjGhSLH3sbNjS6Ugv2jc9xKYbpLB6MUg',
#      'width': 4032}],
#    'place_id': 'ChIJ17u-oW4LxkcRwJGllWAA200',
#    'plus_code': {'compound_code': '8VPC+H5 Amsterdam, Netherlands',
#     'global_code': '9F468VPC+H5'},
#    'rating': 4.5,
#    'reference': 'ChIJ17u-oW4LxkcRwJGllWAA200',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 47},
#   {'formatted_address': 'Binnenhof 7c, 1181 GE Amstelveen, Netherlands',
#    'geometry': {'location': {'lat': 52.30287, 'lng': 4.8617459},
#     'viewport': {'northeast': {'lat': 52.30415517989272,
#       'lng': 4.863368979892722},
#      'southwest': {'lat': 52.30145552010728, 'lng': 4.860669320107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'b29f1913815bc8d382ec920871b4277d8739de32',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101540374974403467266/photos">Stephan Scheffer</a>'],
#      'photo_reference': 'CmRaAAAAXqkqJOTIFy38pt2gMEwAbb1B1fcvV7nSLEtZRTUq11fDRj18jCuFjr77CsBVrWRFHJTduaQEywLUJyHcEDBAg1LJbQoVQYRWT80tNTsBO2ISdw_6eLvtGyuavh7YefkHEhAL44jB93XqXm13uxWEIaL2GhQ899VnNGIUM8O2E2JRLGVqDtfSig',
#      'width': 1080}],
#    'place_id': 'ChIJw4TUv4AKxkcRqsQFmQDS9zg',
#    'plus_code': {'compound_code': '8V36+4M Amstelveen, Netherlands',
#     'global_code': '9F468V36+4M'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJw4TUv4AKxkcRqsQFmQDS9zg',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 260},
#   {'formatted_address': 'Accraweg 19, 1047 HJ Amsterdam, Netherlands',
#    'geometry': {'location': {'lat': 52.4124503, 'lng': 4.7535798},
#     'viewport': {'northeast': {'lat': 52.41392487989272,
#       'lng': 4.754895579892722},
#      'southwest': {'lat': 52.41122522010727, 'lng': 4.752195920107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'a83a37257b747f788400089868a380379bf6b751',
#    'name': 'Starbucks Manufacturing Emea BV',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100069654497300030284/photos">Martin Meijerink</a>'],
#      'photo_reference': 'CmRaAAAAq4wks-L407Pbhy_wlmjvSzHrRWF-hu1V0Kud4nsDNeWf5Kn9Uc3VozfvQNidCa5eMr1h2wJ2LUAbbs1-bXYElo-wJxXquCZbRU5eWm0QkgYywU-8_7ayx0fgU6ezNOskEhD6uOqDdSUGFpE17PzmSq_UGhTSkLNlu9gbch6nahJf94jmvZhKTQ',
#      'width': 4128}],
#    'place_id': 'ChIJLZasAJfkxUcRahqvXnpOgDQ',
#    'plus_code': {'compound_code': 'CQ63+XC Amsterdam, Netherlands',
#     'global_code': '9F46CQ63+XC'},
#    'rating': 2,
#    'reference': 'ChIJLZasAJfkxUcRahqvXnpOgDQ',
#    'types': ['food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5}],
#  'status': 'OK'}

# %%
print(len(places_result['results']))
places_result['results'][19]['name']
# Out:
# 20
# 'Starbucks Manufacturing Emea BV'

# %%
places_result['results'][0]['geometry']['location']
# Out:
# {'lat': 52.37429770000001, 'lng': 4.8942746}

# %%
def getLocation(companies):
    location =[]
    for i in range(len(companies['results'])):
        longitude = companies['results'][i]['geometry']['location']['lng']
        latitude = companies['results'][i]['geometry']['location']['lat']
        name=companies['results'][i]['name']
        loc = {
            'name': name,
            'type':'Point',
            'coordinates':[longitude, latitude]
        }
        location.append(loc)
    return location

# %%
getLocation(places_result)
# Out:
# [{'name': 'STARBUCKS COFFEE Amsterdam Damrak Shop',
#   'type': 'Point',
#   'coordinates': [4.8942746, 52.37429770000001]},
#  {'name': 'STARBUCKS COFFEE Bloemenmarkt Shop',
#   'type': 'Point',
#   'coordinates': [4.8896652, 52.36699789999999]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.8905951, 52.3553881]},
#  {'name': 'STARBUCKS COFFEE Leidsestraat Shop',
#   'type': 'Point',
#   'coordinates': [4.8836336, 52.36448240000001]},
#  {'name': 'STARBUCKS COFFEE Doubletree by Hilton Amsterdam Shop',
#   'type': 'Point',
#   'coordinates': [4.9043465, 52.37687829999999]},
#  {'name': 'STARBUCKS The Bank Rembrandtplein',
#   'type': 'Point',
#   'coordinates': [4.8977405, 52.3659541]},
#  {'name': 'STARBUCKS COFFEE Amsterdam Overtoom Shop',
#   'type': 'Point',
#   'coordinates': [4.8758273, 52.36311569999999]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.8731287, 52.33961009999999]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.900354099999999, 52.37904899999999]},
#  {'name': 'Starbucks', 'type': 'Point', 'coordinates': [4.947705, 52.3121749]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.8771144, 52.3493467]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.8375534, 52.3892232]},
#  {'name': 'Starbucks Amsterdam Amstel Station',
#   'type': 'Point',
#   'coordinates': [4.917986099999999, 52.3464775]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.9571149, 52.2940851]},
#  {'name': 'Starbucks Amsterdam Rokin',
#   'type': 'Point',
#   'coordinates': [4.892257499999999, 52.3703102]},
#  {'name': 'Starbucks on the go',
#   'type': 'Point',
#   'coordinates': [4.8896519, 52.32816709999999]},
#  {'name': 'Starbucks IJHal',
#   'type': 'Point',
#   'coordinates': [4.9005785, 52.3798957]},
#  {'name': 'Starbucks',
#   'type': 'Point',
#   'coordinates': [4.870430199999999, 52.3364927]},
#  {'name': 'Starbucks', 'type': 'Point', 'coordinates': [4.8617459, 52.30287]},
#  {'name': 'Starbucks Manufacturing Emea BV',
#   'type': 'Point',
#   'coordinates': [4.7535798, 52.4124503]}]
