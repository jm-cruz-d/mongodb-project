# %%
from pymongo import MongoClient
import folium
import googlemaps
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
def filterType(lat,lng, typeName, radius):
    db, coll = connectCollection('companies', typeName)
    results = coll.find({
        "location":{
            "$near":{
                "$geometry":{
                    "type":"Point",
                    "coordinates":[lng,lat]
                },
                "$maxDistance": radius,
            }
        }
    })
    return results

coords = [52.37021,4.895168]
data = filterType(*coords,'clubs',1000)
print(data.count())
print(data[0])
# Out:
# 20
# {'_id': ObjectId('5dd6ada72eb127ee9342a412'), 'name': 'alfie newell', 'address': '1012 DV Amsterdam, Netherlands', 'location': {'type': 'Point', 'coordinates': [4.895861000000001, 52.3718604]}}
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.

# %%
db, localrent = connectCollection('companies', 'rentlocals')

# %%
lr = localrent.find()

# %%
def distanceFromlocals(coll, radius):
    listlocals = []
    for l in lr:
        listlocals.append(l['location']['coordinates'])
    for ll in listlocals:
        return data = filterType(*ll[::-1], coll, radius)

print(listlocals)
# Out:
# [[4.8115896, 52.4021632], [4.9369403, 52.3480536], [4.882497799999999, 52.3759084], [4.8648476, 52.37328549999999], [4.7859449, 52.3614967], [4.805356700000001, 52.344418], [4.8512083, 52.3827785], [4.8648476, 52.37328549999999], [4.8013445, 52.4081418], [4.7865597, 52.35511839999999], [4.826863299999999, 52.36132240000001], [4.7844578, 52.3603337], [5.940916199999999, 50.9309853], [5.891920499999999, 51.9466695], [4.8135102, 52.374663], [4.892646399999999, 52.3574204], [4.8857715, 52.3557995], [4.8300629, 52.3903184], [4.8883449, 52.3587549], [4.857448900000001, 52.4093513], [4.8721526, 52.3562588], [4.852933, 52.39810139999999], [4.9032244, 52.35573180000001], [4.8660656, 52.3946008], [4.9357212, 52.3684091], [4.7103503, 52.2922644], [4.8115896, 52.4021632], [4.9369403, 52.3480536], [4.882497799999999, 52.3759084], [4.8648476, 52.37328549999999], [4.7859449, 52.3614967], [4.805356700000001, 52.344418], [4.8512083, 52.3827785], [4.8648476, 52.37328549999999], [4.8013445, 52.4081418], [4.7865597, 52.35511839999999], [4.826863299999999, 52.36132240000001], [4.7844578, 52.3603337], [5.940916199999999, 50.9309853], [5.891920499999999, 51.9466695], [4.8135102, 52.374663], [4.892646399999999, 52.3574204], [4.8857715, 52.3557995], [4.8300629, 52.3903184], [4.8883449, 52.3587549], [4.857448900000001, 52.4093513], [4.8721526, 52.3562588], [4.852933, 52.39810139999999], [4.9032244, 52.35573180000001