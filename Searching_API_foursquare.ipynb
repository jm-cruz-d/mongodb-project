# %%
import json
import requests
import sys
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Función para mandar queries a la API
def requestfoursquare(query):
    url = 'https://api.foursquare.com/v2/venues/explore'
    params = dict(
      client_id = os.getenv("CLIENT_ID"),
      client_secret = os.getenv("CLIENT_SECRET"),
      v='20180323',
      ll='52.37021,4.895168',
      query=query,
      limit=200
    )
    resp = requests.get(url=url, params=params)
    print(resp)
    data = json.loads(resp.text)
    return data

# %%
requestfoursquare('categories:school')
# Out:
# <Response [200]>
# {'meta': {'code': 200, 'requestId': '5dd00eca40a7ea001bdb6a0c'},
#  'response': {'suggestedRadius': 1800,
#   'headerLocation': 'De Wallen',
#   'headerFullLocation': 'De Wallen, Amsterdam',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'categories:school',
#   'totalResults': 4,
#   'suggestedBounds': {'ne': {'lat': 52.39869755595381,
#     'lng': 5.206651692614445},
#    'sw': {'lat': 52.222374762629336, 'lng': 4.862273193179185}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52752cb511d21ebf366d86f3',
#        'name': 'De Nieuwe Yogaschool',
#        'contact': {},
#        'location': {'address': 'Laurierstraat 109',
#         'lat': 52.371581126194954,
#         'lng': 4.878668053673027,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.371581126194954,
#           'lng': 4.878668053673027}],
#         'distance': 1131,
#         'postalCode': '1016 PH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Laurierstraat 109',
#          '1016 PH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-52752cb511d21ebf366d86f3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb74b769c7ba35d91169806',
#        'name': 'ITCCA School voor Tai Chi Chuan',
#        'contact': {},
#        'location': {'address': 'Lijnbaansgracht 166',
#         'crossStreet': 'Elandstraat',
#         'lat': 52.36976865239914,
#         'lng': 4.877926761335333,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36976865239914,
#           'lng': 4.877926761335333}],
#         'distance': 1172,
#         'postalCode': '1016 VX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lijnbaansgracht 166 (Elandstraat)',
#          '1016 VX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d101941735',
#          'name': 'Martial Arts Dojo',
#          'pluralName': 'Martial Arts Dojos',
#          'shortName': 'Martial Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4cb74b769c7ba35d91169806-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b97da12f964a520151a35e3',
#        'name': 'Pinsas Restaurant',
#        'contact': {},
#        'location': {'address': 'Spaarndammerstraat 772',
#         'lat': 52.39068288352997,
#         'lng': 4.878394056458453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.39068288352997,
#           'lng': 4.878394056458453}],
#         'distance': 2548,
#         'postalCode': '1013 TJ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spaarndammerstraat 772',
#          '1013 TJ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b97da12f964a520151a35e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f5914200cd6de14f8f0cc5a',
#        'name': 'Old School Projects - Daylight photostudio for world-class results',
#        'contact': {},
#        'location': {'address': 'Eemnesserweg 107',
#         'crossStreet': 'Jan van der Heydenstraat',
#         'lat': 52.230389435053176,
#         'lng': 5.190998124458297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.230389435053176,
#           'lng': 5.190998124458297}],
#         'distance': 25452,
#         'postalCode': '1221CW',
#         'cc': 'NL',
#         'city': 'Hilversum',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Eemnesserweg 107 (Jan van der Heydenstraat)',
#          '1221CW Hilversum',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'shortName': 'Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41166113'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4f5914200cd6de14f8f0cc5a-3'}]}]}}
