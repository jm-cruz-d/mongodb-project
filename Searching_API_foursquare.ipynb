# %%
import json
import requests
import sys
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Función para mandar queries a la API
def requestfoursquare(query):
    url = 'https://api.foursquare.com/v2/venues/explore'
    params = dict(
      client_id = os.getenv("CLIENT_ID"),
      client_secret = os.getenv("CLIENT_SECRET"),
      v='20180323',
      ll='52.37021,4.895168',
      query=query,
      limit=200
    )
    resp = requests.get(url=url, params=params)
    print(resp)
    data = json.loads(resp.text)
    return data

# %%
requestfoursquare('categories:Starbucks')
# Out:
# <Response [200]>
# {'meta': {'code': 200, 'requestId': '5dcfe920949393001bc1fa15'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 1800,
#   'headerLocation': 'De Wallen',
#   'headerFullLocation': 'De Wallen, Amsterdam',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'categories:starbucks',
#   'totalResults': 44,
#   'suggestedBounds': {'ne': {'lat': 52.55873414269114,
#     'lng': 6.180711368942426},
#    'sw': {'lat': 51.39046753171415, 'lng': 4.223773972440963}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f019124a69d45461f2458e7',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Utrechtsestraat 9',
#         'lat': 52.36607678472145,
#         'lng': 4.897430803910262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36607678472145,
#           'lng': 4.897430803910262}],
#         'distance': 485,
#         'postalCode': '1017 CV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Utrechtsestraat 9',
#          '1017 CV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4f019124a69d45461f2458e7-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529634bc11d2ab5263ab848c',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Damrak 80-81',
#         'lat': 52.37420747467302,
#         'lng': 4.894578877866116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37420747467302,
#           'lng': 4.894578877866116}],
#         'distance': 446,
#         'postalCode': '1012 LN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Damrak 80-81',
#          '1012 LN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-529634bc11d2ab5263ab848c-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d163ef28132b9002350317e',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Rokin 74',
#         'lat': 52.370311,
#         'lng': 4.892237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.370311,
#           'lng': 4.892237}],
#         'distance': 199,
#         'postalCode': '1012 KW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Норт-Холланд',
#         'country': 'Nederland',
#         'formattedAddress': ['Rokin 74', '1012 KW Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5d163ef28132b9002350317e-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5159308de4b079b32cff96d2',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Singel 480',
#         'lat': 52.36718740588466,
#         'lng': 4.889645408882997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36718740588466,
#           'lng': 4.889645408882997}],
#         'distance': 504,
#         'postalCode': '1017 AW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 480', '1017 AW Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5159308de4b079b32cff96d2-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50056329e4b0c7e958812543',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Oosterdoksstraat 4',
#         'crossStreet': 'Double Tree by Hilton',
#         'lat': 52.37679944948373,
#         'lng': 4.904433482987964,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37679944948373,
#           'lng': 4.904433482987964}],
#         'distance': 966,
#         'postalCode': '1001 RD',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterdoksstraat 4 (Double Tree by Hilton)',
#          '1001 RD Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-50056329e4b0c7e958812543-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9f4ce483f0b1f7ac8996c7',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Leidsestraat 101',
#         'lat': 52.36457890923462,
#         'lng': 4.8835384560699575,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36457890923462,
#           'lng': 4.8835384560699575}],
#         'distance': 1008,
#         'postalCode': '1017 NZ',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Leidsestraat 101',
#          '1017 NZ Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-4d9f4ce483f0b1f7ac8996c7-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b874be498e1798d766b009',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Amsterdam Centraal',
#         'crossStreet': 'Stationsplein 9',
#         'lat': 52.37987266110316,
#         'lng': 4.900730148242557,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37987266110316,
#           'lng': 4.900730148242557}],
#         'distance': 1140,
#         'postalCode': '1012 AB',
#         'cc': 'NL',
#         'neighborhood': 'Stadsdeel Centrum',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Amsterdam Centraal (Stationsplein 9)',
#          '1012 AB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-56b874be498e1798d766b009-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af3e8e7f964a52099ef21e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Amsterdam Centraal',
#         'crossStreet': 'Spoor 2b',
#         'lat': 52.37911719700554,
#         'lng': 4.899273338649127,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37911719700554,
#           'lng': 4.899273338649127}],
#         'distance': 1030,
#         'postalCode': '1012 AB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Amsterdam Centraal (Spoor 2b)',
#          '1012 AB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-4af3e8e7f964a52099ef21e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538f4c36498e102acb282eaf',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Amsterdam Centraal',
#         'crossStreet': 'West Tunnel',
#         'lat': 52.378911,
#         'lng': 4.899253,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.378911,
#           'lng': 4.899253}],
#         'distance': 1007,
#         'postalCode': '1012 AB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Amsterdam Centraal (West Tunnel)',
#          '1012 AB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-538f4c36498e102acb282eaf-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4ed151deabf04dc741c624',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Beethovenstraat 36-38',
#         'lat': 52.34924643340836,
#         'lng': 4.877431666712979,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.34924643340836,
#           'lng': 4.877431666712979}],
#         'distance': 2626,
#         'postalCode': '1077 JH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Beethovenstraat 36-38',
#          '1077 JH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4d4ed151deabf04dc741c624-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51239e248302d014b31b536e',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Amsterdam Amstel',
#         'crossStreet': 'Julianaplein 1',
#         'lat': 52.34665355873868,
#         'lng': 4.91797850350012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.34665355873868,
#           'lng': 4.91797850350012}],
#         'distance': 3046,
#         'postalCode': '1097 DN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Amsterdam Amstel (Julianaplein 1)',
#          '1097 DN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-51239e248302d014b31b536e-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea10e218b81a02f89000add',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Amsterdam Zuid',
#         'crossStreet': 'Zuidplein',
#         'lat': 52.33978268406937,
#         'lng': 4.8732277090758105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.33978268406937,
#           'lng': 4.8732277090758105}],
#         'distance': 3701,
#         'postalCode': '1077 XV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Amsterdam Zuid (Zuidplein)',
#          '1077 XV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ea10e218b81a02f89000add-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a1eb4b11d2d3ce32220aa1',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'IBM Dynatos',
#         'crossStreet': 'David Ricardostraat 2-4',
#         'lat': 52.34108583212485,
#         'lng': 4.829249147137763,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.34108583212485,
#           'lng': 4.829249147137763}],
#         'distance': 5531,
#         'postalCode': '1066 JS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IBM Dynatos (David Ricardostraat 2-4)',
#          '1066 JS Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-52a1eb4b11d2d3ce32220aa1-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1ff491b61cdcf1ecad86f6',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Arena Boulevard 618',
#         'lat': 52.31236212179627,
#         'lng': 4.947476374335735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.31236212179627,
#           'lng': 4.947476374335735}],
#         'distance': 7356,
#         'postalCode': '1011 DS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Arena Boulevard 618',
#          '1011 DS Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4e1ff491b61cdcf1ecad86f6-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '559f74c2498e4096af580076',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'AMC Amsterdam',
#         'crossStreet': 'Meibergdreef 9',
#         'lat': 52.29408296433905,
#         'lng': 4.9574851222568475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.29408296433905,
#           'lng': 4.9574851222568475}],
#         'distance': 9475,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['AMC Amsterdam (Meibergdreef 9)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-559f74c2498e4096af580076-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf211ed6c29236ab1bb69a2',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Concourse D',
#         'crossStreet': 'AMS Airport',
#         'lat': 52.30877203379421,
#         'lng': 4.769041140290995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.30877203379421,
#           'lng': 4.769041140290995}],
#         'distance': 10971,
#         'postalCode': '1117 ZN',
#         'cc': 'NL',
#         'city': 'Hoofddorp',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Concourse D (AMS Airport)',
#          '1117 ZN Hoofddorp',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94121379'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4cf211ed6c29236ab1bb69a2-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc400b6d43ba1438a2a64f8',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Lounge 1',
#         'crossStreet': 'AMS Airport',
#         'lat': 52.30772736659431,
#         'lng': 4.765283474981716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.30772736659431,
#           'lng': 4.765283474981716}],
#         'distance': 11243,
#         'cc': 'NL',
#         'city': 'Schiphol',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lounge 1 (AMS Airport)',
#          'Schiphol',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94121394'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4cc400b6d43ba1438a2a64f8-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d67f959a800721e0df815b8',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Lounge 3',
#         'crossStreet': 'AMS Airport',
#         'lat': 52.311221120012036,
#         'lng': 4.760374327514739,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.311221120012036,
#           'lng': 4.760374327514739}],
#         'distance': 11276,
#         'cc': 'NL',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lounge 3 (AMS Airport)', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94121552'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4d67f959a800721e0df815b8-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5237091f11d24ec6ae4b286d',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Concourse C',
#         'crossStreet': 'AMS Airport',
#         'lat': 52.306720584573924,
#         'lng': 4.7649335861206055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.306720584573924,
#           'lng': 4.7649335861206055}],
#         'distance': 11331,
#         'postalCode': '1117 ZN',
#         'cc': 'NL',
#         'city': 'Schiphol',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Concourse C (AMS Airport)',
#          '1117 ZN Schiphol',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5237091f11d24ec6ae4b286d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a635e5af964a520e2c41fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Schiphol Plaza',
#         'crossStreet': 'AMS Airport',
#         'lat': 52.30972224059859,
#         'lng': 4.762666676333873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.30972224059859,
#           'lng': 4.762666676333873}],
#         'distance': 11249,
#         'postalCode': '1118 ZG',
#         'cc': 'NL',
#         'city': 'Schiphol',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Schiphol Plaza (AMS Airport)',
#          '1118 ZG Schiphol',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94120659'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a635e5af964a520e2c41fe3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '579dcddb498e2ed387907cf6',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'lat': 52.308964,
#         'lng': 4.762517,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.308964,
#           'lng': 4.762517}],
#         'distance': 11308,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-579dcddb498e2ed387907cf6-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5746ec8a498e236ce539c9df',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'The Pavilion',
#         'lat': 52.30992005527378,
#         'lng': 4.765162922235429,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.30992005527378,
#           'lng': 4.765162922235429}],
#         'distance': 11100,
#         'postalCode': '1118 AP',
#         'cc': 'NL',
#         'city': 'Schiphol',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['The Pavilion', '1118 AP Schiphol', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5746ec8a498e236ce539c9df-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '541fd647498e0fca5ac40380',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'The Base',
#         'crossStreet': 'Evert van de Beekstraat 310',
#         'lat': 52.304804857941406,
#         'lng': 4.750951613381454,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.304804857941406,
#           'lng': 4.750951613381454}],
#         'distance': 12215,
#         'postalCode': '1118 CL',
#         'cc': 'NL',
#         'city': 'Schiphol',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['The Base (Evert van de Beekstraat 310)',
#          '1118 CL Schiphol',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-541fd647498e0fca5ac40380-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527cd45c11d2ec15cf3ec92d',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 11',
#         'lat': 52.38747154736541,
#         'lng': 4.6379021726965215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38747154736541,
#           'lng': 4.6379021726965215}],
#         'distance': 17587,
#         'postalCode': '2011 LR',
#         'cc': 'NL',
#         'neighborhood': 'Stationsbuurt',
#         'city': 'Haarlem',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 11',
#          '2011 LR Haarlem',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-527cd45c11d2ec15cf3ec92d-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb11df2cc21adeaf7ebddb8',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 11',
#         'crossStreet': 'Station Hilversum',
#         'lat': 52.22639848706764,
#         'lng': 5.181176825952903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.22639848706764,
#           'lng': 5.181176825952903}],
#         'distance': 25206,
#         'postalCode': '1211 EX',
#         'cc': 'NL',
#         'city': 'Hilversum',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 11 (Station Hilversum)',
#          '1211 EX Hilversum',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4eb11df2cc21adeaf7ebddb8-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53fede8d498e916b57f6eeac',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Shell',
#         'crossStreet': 'Rijksweg A2',
#         'lat': 52.14370072259015,
#         'lng': 5.000954241011001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.14370072259015,
#           'lng': 5.000954241011001}],
#         'distance': 26224,
#         'postalCode': '3621 QQ',
#         'cc': 'NL',
#         'city': 'Breukelen',
#         'state': 'Utrecht',
#         'country': 'Nederland',
#         'formattedAddress': ['Shell (Rijksweg A2)',
#          '3621 QQ Breukelen',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-53fede8d498e916b57f6eeac-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d1ac26498e0a4345fc2630',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Hollandse Toren 97',
#         'lat': 52.09282610016957,
#         'lng': 5.114708036803525,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.09282610016957,
#           'lng': 5.114708036803525}],
#         'distance': 34314,
#         'postalCode': '3511 BN',
#         'cc': 'NL',
#         'city': 'Utrecht',
#         'state': 'Utrecht',
#         'country': 'Nederland',
#         'formattedAddress': ['Hollandse Toren 97',
#          '3511 BN Utrecht',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-51d1ac26498e0a4345fc2630-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aad1130c824ae43b144d2a0',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Catharijne Esplanade 11',
#         'lat': 52.09161341148815,
#         'lng': 5.112884718754506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.09161341148815,
#           'lng': 5.112884718754506}],
#         'distance': 34382,
#         'postalCode': '3511 GB',
#         'cc': 'NL',
#         'neighborhood': 'Hoog-Catharijne CS en Leidseveer',
#         'city': 'Utrecht',
#         'state': 'Utrecht',
#         'country': 'Nederland',
#         'formattedAddress': ['Catharijne Esplanade 11',
#          '3511 GB Utrecht',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5aad1130c824ae43b144d2a0-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa66ed8e4b0fed4828951d2',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Meerndijk 59 B',
#         'lat': 52.0723315,
#         'lng': 5.0281215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.0723315,
#           'lng': 5.0281215}],
#         'distance': 34376,
#         'postalCode': '3454 HP',
#         'cc': 'NL',
#         'city': 'De Meern',
#         'state': 'Utrecht',
#         'country': 'Nederland',
#         'formattedAddress': ['Meerndijk 59 B',
#          '3454 HP De Meern',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94121860'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4fa66ed8e4b0fed4828951d2-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b17f4f7f964a52038ca23e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 3',
#         'lat': 52.165803477299235,
#         'lng': 4.482701060132648,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.165803477299235,
#           'lng': 4.482701060132648}],
#         'distance': 36156,
#         'postalCode': '2312 AJ',
#         'cc': 'NL',
#         'city': 'Leiden',
#         'state': 'Zuid-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 3',
#          '2312 AJ Leiden',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
# ...
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33851913'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4e2031551fc7c0ef9856f370-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b003e52356b49002c99456f',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Hofplein 19',
#         'lat': 51.92559455316974,
#         'lng': 4.477626666275436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.92559455316974,
#           'lng': 4.477626666275436}],
#         'distance': 57123,
#         'postalCode': '3032 AL',
#         'cc': 'NL',
#         'neighborhood': 'Stadsdriehoek',
#         'city': 'Rotterdam',
#         'state': 'Zuid-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Hofplein 19', '3032 AL Rotterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5b003e52356b49002c99456f-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ec0dd3e4b0ecd50cae7172',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': "'s-Gravendijkwal 230",
#         'lat': 51.91023820677671,
#         'lng': 4.466751922463149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.91023820677671,
#           'lng': 4.466751922463149}],
#         'distance': 58978,
#         'postalCode': '3015 CE',
#         'cc': 'NL',
#         'city': 'Rotterdam',
#         'state': 'Zuid-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ["'s-Gravendijkwal 230",
#          '3015 CE Rotterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-50ec0dd3e4b0ecd50cae7172-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c3451aaf96b2c002c174093',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'A12',
#         'lat': 52.024358,
#         'lng': 5.879869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.024358,
#           'lng': 5.879869}],
#         'distance': 77436,
#         'postalCode': '6816AA',
#         'cc': 'NL',
#         'city': 'Arnhem',
#         'state': 'Gelderland',
#         'country': 'Nederland',
#         'formattedAddress': ['A12', '6816AA Arnhem', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5c3451aaf96b2c002c174093-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529ee8db498ea9e1a0867795',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 137',
#         'crossStreet': "Station 's-Hertogenbosch",
#         'lat': 51.690452412086096,
#         'lng': 5.294551011610059,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.690452412086096,
#           'lng': 5.294551011610059}],
#         'distance': 80461,
#         'postalCode': '5211 BM',
#         'cc': 'NL',
#         'city': "'s-Hertogenbosch",
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ["Stationsplein 137 (Station 's-Hertogenbosch)",
#          "5211 BM 's-Hertogenbosch",
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-529ee8db498ea9e1a0867795-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddc5786814d8413e55b06e2',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 151',
#         'lat': 51.98431985424963,
#         'lng': 5.901094345182606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.98431985424963,
#           'lng': 5.901094345182606}],
#         'distance': 80995,
#         'postalCode': '6811 KK',
#         'cc': 'NL',
#         'city': 'Arnhem',
#         'state': 'Gelderland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 151',
#          '6811 KK Arnhem',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ddc5786814d8413e55b06e2-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '542d5029498e56ab9aa809c9',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Oosterlaan 1',
#         'lat': 52.50563111491945,
#         'lng': 6.0917596691014495,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.50563111491945,
#           'lng': 6.0917596691014495}],
#         'distance': 82589,
#         'postalCode': '8011 GA',
#         'cc': 'NL',
#         'city': 'Zwolle',
#         'state': 'Overijssel',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterlaan 1', '8011 GA Zwolle', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-542d5029498e56ab9aa809c9-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540ae1a8498ebb802dae771b',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Stationsplein 16',
#         'lat': 51.596289771895385,
#         'lng': 4.7794417012463075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.596289771895385,
#           'lng': 4.7794417012463075}],
#         'distance': 86516,
#         'postalCode': '4811 BB',
#         'cc': 'NL',
#         'city': 'Breda',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 16',
#          '4811 BB Breda',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-540ae1a8498ebb802dae771b-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee206ff8b816da57c71b839',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Station Nijmegen',
#         'crossStreet': 'Stationsplein 6',
#         'lat': 51.84351159198047,
#         'lng': 5.853016311502425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.84351159198047,
#           'lng': 5.853016311502425}],
#         'distance': 87898,
#         'postalCode': '6512 AB',
#         'cc': 'NL',
#         'city': 'Nijmegen',
#         'state': 'Gelderland',
#         'country': 'Nederland',
#         'formattedAddress': ['Station Nijmegen (Stationsplein 6)',
#          '6512 AB Nijmegen',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ee206ff8b816da57c71b839-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53f226e3498e24d7e7fac355',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Warandelaan 2',
#         'lat': 51.56346423709185,
#         'lng': 5.04240168355135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.56346423709185,
#           'lng': 5.04240168355135}],
#         'distance': 90371,
#         'postalCode': '5037AB',
#         'cc': 'NL',
#         'city': 'Tilburg',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Warandelaan 2', '5037AB Tilburg', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-53f226e3498e24d7e7fac355-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57e52461498e1a900e691eea',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Neckerspoel',
#         'lat': 51.44357055948583,
#         'lng': 5.479347819125641,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.44357055948583,
#           'lng': 5.479347819125641}],
#         'distance': 110678,
#         'postalCode': '5611 AD',
#         'cc': 'NL',
#         'city': 'Eindhoven',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Neckerspoel', '5611 AD Eindhoven', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-57e52461498e1a900e691eea-43'}]}]}}
