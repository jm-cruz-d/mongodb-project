# %%
import folium

# %%
# %store -r

# %%
# %store
# Out:
# Stored variables and their in-db values:
# a                 -> [{'name': 'Vegan Junk Food Bar', 'type': 'Point',
# aloc              -> [{'name': 'Schiphol', 'type': 'Point', 'coordinate
# comp              -> [{'_id': ObjectId('52cdef7c4bab8bd675297de6'), 'na
# comp2             -> [{'_id': ObjectId('52cdef7c4bab8bd675297de6'), 'na
# kdloc             -> [{'name': 'The Little Prince', 'type': 'Point', 'c
# ncloc             -> [{'name': "Stone's Café Bar & Nightclub", 'type':
# sbloc             -> [{'name': 'STARBUCKS COFFEE Leidsestraat Shop', 't
# scloc             -> [{'name': 'Oecumenische Basisschool Elout', 'type'
# vrloc             -> [{'name': 'Vegan Junk Food Bar', 'type': 'Point',

# %%
map_city=folium.Map(location=[52.37021,4.895168], zoom_start=12)
for cmp in comp2:
    for i in range(len(cmp['location'])):
        folium.Marker(cmp['location'][i]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='home',color='red'), 
                   ).add_to(map_city)

for al in aloc:
    folium.Marker(al['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='black'), 
                   ).add_to(map_city)

for kd in kdloc:
    folium.Marker(kd['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='blue'), 
                   ).add_to(map_city)

for nc in ncloc:
    folium.Marker(nc['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='purple'), 
                   ).add_to(map_city)

for sb in sbloc:
    folium.Marker(sb['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='green'), 
                   ).add_to(map_city)

for sc in scloc:
    folium.Marker(sc['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='orange'), 
                   ).add_to(map_city)

for vr in vrloc:
    folium.Marker(vr['coordinates'],
                    radius=2,
                    icon=folium.Icon(icon='home',color='white'), 
                   ).add_to(map_city)

# %%
map_city
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
