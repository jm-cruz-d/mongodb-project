# %%
import folium

# %%
# %store -r

# %%
# %store
# Out:
# Stored variables and their in-db values:
# a                 -> [{'name': 'Vegan Junk Food Bar', 'type': 'Point',
# aloc              -> [{'name': 'Schiphol', 'type': 'Point', 'coordinate
# comp              -> [{'_id': ObjectId('52cdef7c4bab8bd675297de6'), 'na
# comp2             -> [{'_id': ObjectId('52cdef7c4bab8bd675297de6'), 'na
# kdloc             -> [{'name': 'The Little Prince', 'type': 'Point', 'c
# ncloc             -> [{'name': "Stone's Café Bar & Nightclub", 'type':
# sbloc             -> [{'name': 'STARBUCKS COFFEE Leidsestraat Shop', 't
# scloc             -> [{'name': 'Oecumenische Basisschool Elout', 'type'
# vrloc             -> [{'name': 'Vegan Junk Food Bar', 'type': 'Point',
# x                 -> [{'address': 'Corsicaweg 10', 'coordinates': [4.81

# %%
map_city=folium.Map(location=[52.37021,4.895168], zoom_start=12)
for cmp in comp2:
    for i in range(len(cmp['location'])):
        folium.Marker(cmp['location'][i]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='usd',color='red'), 
                   ).add_to(map_city)

for al in aloc:
    folium.Marker(al['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='plane',color='black'), 
                   ).add_to(map_city)

for kd in kdloc:
    folium.Marker(kd['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='heart',color='blue'), 
                   ).add_to(map_city)

for nc in ncloc:
    folium.Marker(nc['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='glass',color='purple'), 
                   ).add_to(map_city)

for sb in sbloc:
    folium.Marker(sb['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='fire',color='darkgreen'), 
                   ).add_to(map_city)

for sc in scloc:
    folium.Marker(sc['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='book',color='orange'), 
                   ).add_to(map_city)

for vr in vrloc:
    folium.Marker(vr['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='cutlery',color='cadetblue'), 
                   ).add_to(map_city)

for x1 in x:
    folium.Marker(x1['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='home',color='beige'), 
                   ).add_to(map_city)


    
# color_options = {'beige', 'black', 'blue', 'cadetblue', 'darkblue', 'darkgreen', 'darkpurple', 'darkred',
# 'gray', 'green', 'lightblue', 'lightgray', 'lightgreen', 'lightred', 'orange', 'pink', 'purple', 'red', 'white'}

# %%
map_city
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
